# %% [markdown]
# # About Dataset
# This dataset provides an extensive overview of the most used beauty and cosmetics products across the world, offering insights into global trends, preferences, and popular brands. It includes detailed information about product names, brands, categories, usage frequency, pricing, user ratings, reviews, and more.
#
# Whether you're a researcher, marketer, or beauty enthusiast, this dataset serves as a valuable resource for understanding consumer behavior, brand popularity, and market trends within the beauty industry. It can also be used for market analysis, trend predictions, and even building recommendation systems for beauty products.
#
# 💅 Categories Covered:
#
# Skincare: Moisturizers, sunscreens, cleansers, etc.
# Makeup: Lipsticks, foundations, eyeliners, etc.
# Haircare: Shampoos, conditioners, treatments, etc.
# Fragrances: Perfumes, body sprays, etc.
# Personal Care: Deodorants, body lotions, etc.
#
# ✨ Key Features:
#
# Product Details: Includes product names, brands, and categories.
# Pricing: Provides the product price in USD.
# User Ratings: Ratings out of 5, indicating customer satisfaction.
# Reviews: Number of reviews per product, highlighting popularity.
# Usage Frequency: Daily, weekly, monthly, or occasional usage patterns.
#
# 🔍 Use Cases:
#
# Market research on beauty and cosmetics trends.
# Building recommendation systems for beauty products.
# Analyzing brand popularity and customer feedback.
# Creating targeted marketing strategies.

# %% [markdown]
# ************

# %% [markdown]
# ## The dataset contains 15,000 entries and 14 columns. Here's a summary of the columns:
#
# Product_Name: Name of the cosmetic product (string).
#
# Brand: Brand associated with the product (string).
#
# Category: Type or category of the product (e.g., Blush, Highlighter) (string).
#
# Usage_Frequency: Frequency of use (e.g., Daily, Weekly, Occasional) (string).
#
# Price_USD: Price of the product in USD (float).
#
# Rating: Average customer rating of the product (float).
#
# Number_of_Reviews: Number of customer reviews (integer).
#
# Product_Size: Size of the product (e.g., 30ml, 100ml) (string).
#
# Skin_Type: Type of skin the product is suitable for (e.g., Sensitive, Oily) (string).
#
# Gender_Target: Gender targeted by the product (e.g., Female, Male, Unisex) (string).
#
# Packaging_Type: Type of packaging (e.g., Tube, Bottle, Compact) (string).
#
# Main_Ingredient: Primary ingredient in the product (e.g., Retinol, Aloe Vera) (string).
#
# Cruelty_Free: Indicates whether the product is cruelty-free (boolean).
#
# Country_of_Origin: Country where the product is manufactured (string).
#
# # Sample Data:
# The first product, "Ultra Face Mask" by Drunk Elephant, is a blush product priced at $67.85, with a low rating of 1.4 and 686 reviews.
# It comes in a 30ml tube, is targeted at sensitive skin for females, and is not cruelty-free, originating from Australia.

# %% [markdown]
# ***************

# %% [markdown]
# # collect data using any method we learned before then apply:
#
# 1- Data Understanding (to see all data values)
#
# 2- EDA (univariate + bi-variate + multivariate) to get insights about your data.
#
# you may put the 10 business questions in the bi-varaite part ^^.
#
# 3- Mix between plotly and (seaborn + matplotlib.pyplot visualizations) in your results
#
# 4- Use the appropriate statistical methods to answer the business questions
#
# 5- Write a clear and concise report that includes all the steps you took, the results you got
#
# and the answers to the business questions.

# %% [markdown]
# ***********

# %% [markdown]
# ## 1- Data Understanding (to see all data values)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib .pyplot as plt
import plotly.express as px
import streamlit as st

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv('most_used_beauty_cosmetics_products_extended.csv')
df
# Out:
#            Product_Name              Brand        Category Usage_Frequency  \
# 0       Ultra Face Mask     Drunk Elephant           Blush          Weekly
# 1        Ultra Lipstick      Laura Mercier  Makeup Remover      Occasional
# 2           Ultra Serum     Natasha Denona     Highlighter           Daily
# 3          Divine Serum        Ilia Beauty       Face Mask      Occasional
# 4      Super Foundation  Charlotte Tilbury     Highlighter      Occasional
# ...                 ...                ...             ...             ...
# 14995    Magic Eyeliner         Patrick Ta       Face Mask           Daily
# 14996    Perfect Powder            Farsali           Serum          Weekly
# 14997       Magic Serum            Kiehl’s     Highlighter      Occasional
# 14998     Magic Mascara       Perricone MD          Powder          Weekly
# 14999  Divine Lip Liner             Tatcha           Blush           Daily
#
# ...

# %%
df.head()
# Out:
#        Product_Name              Brand        Category Usage_Frequency  \
# 0   Ultra Face Mask     Drunk Elephant           Blush          Weekly
# 1    Ultra Lipstick      Laura Mercier  Makeup Remover      Occasional
# 2       Ultra Serum     Natasha Denona     Highlighter           Daily
# 3      Divine Serum        Ilia Beauty       Face Mask      Occasional
# 4  Super Foundation  Charlotte Tilbury     Highlighter      Occasional
#
#    Price_USD  Rating  Number_of_Reviews Product_Size  Skin_Type Gender_Target  \
# 0      67.85     1.4                686         30ml  Sensitive        Female
# 1     116.43     4.2               5483        250ml        Dry        Unisex
# 2      90.84     1.6               5039        100ml  Sensitive          Male
# 3      55.17     3.2               6202        250ml     Normal          Male
# 4     140.56     1.7                297        100ml       Oily        Female
#
#   Packaging_Type Main_Ingredient  Cruelty_Free Country_of_Origin
# ...

# %%
print(df.columns)
# Out:
# Index(['Product_Name', 'Brand', 'Category', 'Usage_Frequency', 'Price_USD',
#        'Rating', 'Number_of_Reviews', 'Product_Size', 'Skin_Type',
#        'Gender_Target', 'Packaging_Type', 'Main_Ingredient', 'Cruelty_Free',
#        'Country_of_Origin'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Product_Name       15000 non-null  object
#  1   Brand              15000 non-null  object
#  2   Category           15000 non-null  object
#  3   Usage_Frequency    15000 non-null  object
#  4   Price_USD          15000 non-null  float64
#  5   Rating             15000 non-null  float64
#  6   Number_of_Reviews  15000 non-null  int64
#  7   Product_Size       15000 non-null  object
#  8   Skin_Type          15000 non-null  object
#  9   Gender_Target      15000 non-null  object
#  10  Packaging_Type     15000 non-null  object
#  11  Main_Ingredient    15000 non-null  object
#  12  Cruelty_Free       15000 non-null  bool
#  13  Country_of_Origin  15000 non-null  object
# dtypes: bool(1), float64(2), int64(1), object(10)
# memory usage: 1.5+ MB

# %%
# missing

for col in df.columns:
    data_missing = np.mean(df[col].isnull()) * 100
    print("{} - {}%".format(col, data_missing))
# Out:
# Product_Name - 0.0%
# Brand - 0.0%
# Category - 0.0%
# Usage_Frequency - 0.0%
# Price_USD - 0.0%
# Rating - 0.0%
# Number_of_Reviews - 0.0%
# Product_Size - 0.0%
# Skin_Type - 0.0%
# Gender_Target - 0.0%
# Packaging_Type - 0.0%
# Main_Ingredient - 0.0%
# Cruelty_Free - 0.0%
# Country_of_Origin - 0.0%

# %%
df.describe()
# Out:
#           Price_USD        Rating  Number_of_Reviews
# count  15000.000000  15000.000000       15000.000000
# mean      80.134108      3.002327        5014.231333
# std       40.402983      1.168029        2855.665464
# min       10.000000      1.000000          52.000000
# 25%       45.480000      2.000000        2562.000000
# 50%       80.040000      3.000000        5002.000000
# 75%      114.760000      4.000000        7497.000000
# max      149.990000      5.000000       10000.000000

# %%
df.select_dtypes(include=['object']).describe()
# Out:
#                Product_Name        Brand Category Usage_Frequency  \
# count                 15000        15000    15000           15000
# unique                  120           40       24               4
# top     Super Setting Spray  Milk Makeup    Serum      Occasional
# freq                    154          426      710            3794
#
#        Product_Size    Skin_Type Gender_Target Packaging_Type Main_Ingredient  \
# count         15000        15000         15000          15000           15000
# unique            6            5             3              6               7
# top           100ml  Combination          Male            Jar         Retinol
# freq           2551         3060          5017           2567            2180
#
#        Country_of_Origin
# count              15000
# unique                 8
# top                Italy
# freq                1942

# %%
df.select_dtypes(include=['float']).describe()
# Out:
#           Price_USD        Rating
# count  15000.000000  15000.000000
# mean      80.134108      3.002327
# std       40.402983      1.168029
# min       10.000000      1.000000
# 25%       45.480000      2.000000
# 50%       80.040000      3.000000
# 75%      114.760000      4.000000
# max      149.990000      5.000000

# %%
df.select_dtypes(include=['int']).describe()
# Out:
#        Number_of_Reviews
# count       15000.000000
# mean         5014.231333
# std          2855.665464
# min            52.000000
# 25%          2562.000000
# 50%          5002.000000
# 75%          7497.000000
# max         10000.000000

# %%
df.select_dtypes(include=['bool']).describe()
# Out:
#        Cruelty_Free
# count         15000
# unique            2
# top           False
# freq           7592

# %%
categorical_columns = df.select_dtypes(include="O").columns
for col in categorical_columns:
    print(f"the number of uniques in \'{col}\'is {df[col].nunique()}")
    print(f"the uniques in \'{col}\' are {df[col].unique()}") 
    print()
    print("*" * 60)
    print()
# Out:
# the number of uniques in 'Product_Name'is 120
# the uniques in 'Product_Name' are ['Ultra Face Mask' 'Ultra Lipstick' 'Ultra Serum' 'Divine Serum'
#  'Super Foundation' 'Super Eye Shadow' 'Super Lip Gloss' 'Ultra Cleanser'
#  'Magic Highlighter' 'Perfect Bronzer' 'Ultra Moisturizer'
#  'Divine CC Cream' 'Ultra Setting Spray' 'Divine Primer'
#  'Divine Exfoliator' 'Perfect Blush' 'Perfect Highlighter'
#  'Super Cleanser' 'Ultra Face Oil' 'Divine Lip Gloss' 'Divine Foundation'
#  'Divine Cleanser' 'Perfect Eyeliner' 'Super Serum' 'Divine Setting Spray'
#  'Magic Eye Shadow' 'Ultra Exfoliator' 'Magic Lip Liner'
#  'Super Makeup Remover' 'Perfect BB Cream' 'Magic BB Cream'
#  'Super Lip Liner' 'Ultra Lip Gloss' 'Super Primer' 'Divine Eyeliner'
#  'Super Contour' 'Magic Makeup Remover' 'Perfect Face Mask'
#  'Perfect Contour' 'Perfect Lip Liner' 'Magic Setting Spray'
#  'Magic CC Cream' 'Super Exfoliator' 'Perfect Eye Shadow'
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# 1) "What is the highest product rating, and what is the name of the product with that rating?"

# %%
# the highest product rating
highest_product = df['Rating'].max()
highest_product_index = df['Rating'].idxmax()
# the name of the product with that rating
Product_Name = df.loc[highest_product_index, 'Product_Name']
print("The highest product Rate is:", highest_product)
print("The name of product that is:", Product_Name)
# Out:
# The highest product Rate is: 5.0
# The name of product that is: Divine Bronzer

# %% [markdown]
# 2) "What is the lowest product rating, and what is the name of the product with that rating?"

# %%
lowest_rate = df['Rating'].min()
lowest_rate_index = df['Rating'].idxmin()
student_name = df.loc[lowest_rate_index, 'Product_Name']
print("The lowest product rating is:", lowest_rate)
print("The  name of the product with that ratingt is:", student_name)
# Out:
# The lowest product rating is: 1.0
# The  name of the product with that ratingt is: Ultra Lip Gloss

# %% [markdown]
# 3) "Which beauty brands are the most popular?"

# %%
top_brands = df['Brand'].value_counts().nlargest(10)
print(top_brands)
# Out:
# Brand
# Milk Makeup           426
# Make Up For Ever      414
# Kiehl’s               411
# NARS                  400
# E.l.f.                399
# Farsali               399
# Yves Saint Laurent    394
# Morphe                392
# Bite Beauty           392
# Sisley                392
# Name: count, dtype: int64

# %%
top_brands = df['Brand'].value_counts().nlargest(3)
print(top_brands)
# Out:
# Brand
# Milk Makeup         426
# Make Up For Ever    414
# Kiehl’s             411
# Name: count, dtype: int64

# %% [markdown]
# 4) "What are the most common main ingredients used in beauty products?"

# %%
main_ingredients = df['Main_Ingredient'].value_counts().nlargest(10)
print(main_ingredients)
# Out:
# Main_Ingredient
# Retinol            2180
# Glycerin           2174
# Vitamin C          2168
# Salicylic Acid     2149
# Shea Butter        2148
# Aloe Vera          2091
# Hyaluronic Acid    2090
# Name: count, dtype: int64

# %% [markdown]
# 5) "What are the most common packaging types for beauty products?"

# %%
# packaging_type_counts = df['Packaging_Type'].value_counts()
# print(packaging_type_counts)

# %% [markdown]
# 6) "Which beauty products have received the most customer reviews?"

# %%
top_reviews = df[['Product_Name', 'Number_of_Reviews']].sort_values(by='Number_of_Reviews', ascending=False).head(10)
top_reviews
# Out:
#             Product_Name  Number_of_Reviews
# 11401   Ultra Eye Shadow              10000
# 9497    Ultra Foundation               9999
# 5325      Super Cleanser               9999
# 3325       Magic Mascara               9999
# 3121       Super Mascara               9999
# 3149      Ultra CC Cream               9999
# 2839   Divine Foundation               9998
# 8906      Ultra Cleanser               9997
# 11779      Perfect Blush               9997
# 6289     Magic Lip Gloss               9997

# %% [markdown]
# 7) "Which countries are known for producing higher-priced beauty products?"

# %%
# Group by 'Country' and calculate the average price of beauty products for each country
average_price_per_country = df.groupby('Country_of_Origin')['Price_USD'].mean()

# Sort the countries by the average price in descending order to find the countries with the highest-priced products
top_countries = average_price_per_country.sort_values(ascending=False)

# Display the countries with the highest average prices
print(top_countries)
# Out:
# Country_of_Origin
# South Korea    82.399914
# Australia      80.738372
# USA            80.496794
# Germany        80.342248
# Italy          79.927225
# France         79.243027
# UK             79.159697
# Japan          78.765465
# Name: Price_USD, dtype: float64

# %% [markdown]
# 8) "What is the proportion of beauty products designed for different skin types?"

# %%
skin_type_counts = df['Skin_Type'].value_counts()
skin_type_counts
# Out:
# Skin_Type
# Combination    3060
# Oily           3009
# Normal         2991
# Sensitive      2975
# Dry            2965
# Name: count, dtype: int64

# %% [markdown]
# 9) "How does product size (ml) correlate with pricing and customer reviews?"

# %%
# Remove 'ml' from the Product_Size column and convert it to float
df['Product_Size'] = df['Product_Size'].str.replace('ml', '').astype(float)

# Now calculate the correlation matrix with the correct columns
print("Correlation matrix:")
print(df[['Product_Size', 'Price_USD', 'Rating', 'Number_of_Reviews']].corr())
# Out:
# Correlation matrix:
#                    Product_Size  Price_USD    Rating  Number_of_Reviews
# Product_Size           1.000000  -0.008668 -0.005624          -0.010334
# Price_USD             -0.008668   1.000000 -0.005232          -0.005567
# Rating                -0.005624  -0.005232  1.000000          -0.002428
# Number_of_Reviews     -0.010334  -0.005567 -0.002428           1.000000

# %% [markdown]
# 10) "Do cruelty-free products ( have not been tested on animals at any stage of their development) tend to be more expensive or higher-rated compared to non-cruelty-free products?"

# %%
cruelty_free_prices = df.groupby('Cruelty_Free')['Price_USD'].mean()
cruelty_free_ratings = df.groupby('Cruelty_Free')['Rating'].mean()
cruelty_free_prices
cruelty_free_ratings
# Out:
# Cruelty_Free
# False    2.999065
# True     3.005670
# Name: Rating, dtype: float64

# %%
# Create a function to calculate the average price range for beauty brands
def calculate_average_price_range(df):
    # Check if 'Brand' column exists
    if 'Brand' not in df.columns:
        raise ValueError("DataFrame must contain a 'Brand' column.")
        
    # Group by brand and calculate average price
    average_price_data = df.groupby('Brand')['Price_USD'].agg(['min', 'max']).reset_index()
    average_price_data['average_price'] = (average_price_data['min'] + average_price_data['max']) / 2
    return average_price_data[['Brand', 'average_price']]  # Corrected to return both columns

# Function to sort the brands by their average price range
def sort_brands_by_average_price(average_price_data):
    return average_price_data.sort_values(by='average_price')

# Calculate the average price range for each brand
average_price_data = calculate_average_price_range(df)

# Sort the brands by their average price range
sorted_brands = sort_brands_by_average_price(average_price_data)

# Print the sorted list of beauty brands with their average price ranges
for index, brand in sorted_brands.iterrows():
    print(f"{brand['Brand']}: ${brand['average_price']:.2f}")  # Corrected the indexing to 'Brand'
# Out:
# Drunk Elephant: $79.29
# Bourjois: $79.50
# Bobby Brown: $79.50
# Perricone MD: $79.63
# Sisley: $79.69
# Tatcha: $79.72
# Too Faced: $79.83
# Becca: $79.86
# Kylie Cosmetics: $79.86
# Ilia Beauty: $79.88
# KVD Beauty: $79.88
# E.l.f.: $79.89
# Farsali: $79.91
# Bite Beauty: $79.92
# IT Cosmetics: $79.94
# Glossier: $79.96
# Make Up For Ever: $79.96
# Morphe: $79.97
# Kiehl’s: $79.99
# Patrick Ta: $80.02
# Hourglass: $80.03
# Milk Makeup: $80.04
# Tarte: $80.05
# NARS: $80.05
# Huda Beauty: $80.06
# Urban Decay: $80.09
# Anastasia Beverly Hills: $80.11
# Yves Saint Laurent: $80.16
# RMS Beauty: $80.19
# Pat McGrath Labs: $80.21
# Laura Mercier: $80.22
# Fenty Beauty: $80.25
# Clinique: $80.26
# Natasha Denona: $80.27
# Danessa Myricks: $80.32
# Charlotte Tilbury: $80.34
# ColourPop: $80.34
# Shiseido: $80.36
# Rare Beauty: $80.36
# Juvia’s Place: $80.48

# %% [markdown]
# How does the packaging type (e.g., tube, bottle, compact) influence customer satisfaction or reviews?

# %%
# Convert Packaging_Type to categorical variable
df['Packaging_Type'] = pd.Categorical(df['Packaging_Type'])

# One-hot encode Packaging_Type
packaging_type_dummies = pd.get_dummies(df['Packaging_Type'], prefix='Packaging_Type')
df['Packaging_Type']
# Out:
# 0           Tube
# 1         Bottle
# 2        Compact
# 3           Tube
# 4        Compact
#           ...
# 14995       Tube
# 14996        Jar
# 14997        Jar
# 14998        Jar
# 14999     Bottle
# Name: Packaging_Type, Length: 15000, dtype: category
# Categories (6, object): ['Bottle', 'Compact', 'Jar', 'Spray', 'Stick', 'Tube']

# %% [markdown]
# Which gender (male, female, unisex) is targeted the most by high-priced products?

# %%
avg_prices = df.groupby('Gender_Target')['Price_USD'].mean()

# Print the results
print("Average prices by gender:")
print(avg_prices)
# Out:
# Average prices by gender:
# Gender_Target
# Female    79.990054
# Male      80.256127
# Unisex    80.155868
# Name: Price_USD, dtype: float64

# %%
top_brands = df.pivot_table(
    index = 'Brand',
    aggfunc = {'Product_Name' : 'count', 'Price_USD' : "mean", 'Rating' : "mean", 'Number_of_Reviews' : "sum"}
    ).reset_index().sort_values(by='Product_Name', ascending = False)

top_brands = top_brands.rename(columns={'Product_Name': 'Total_Nop', 'Price_USD' : "Avg_price", 'Rating' : "Avg_Rating"})
top_brands_10 = top_brands.head(10)
top_brands_10
# Out:
#                  Brand  Number_of_Reviews  Avg_price  Total_Nop  Avg_Rating
# 24         Milk Makeup            2052960  78.991408        426    3.146479
# 23    Make Up For Ever            2014502  82.462077        414    2.971498
# 20             Kiehl’s            2029989  77.478491        411    2.938929
# 26                NARS            2089857  76.337625        400    3.001750
# 10              E.l.f.            2026679  79.595714        399    3.012782
# 11             Farsali            1956526  81.286090        399    2.995489
# 39  Yves Saint Laurent            1985712  80.976777        394    2.978173
# 34              Sisley            1974363  78.275357        392    3.043878
# 2          Bite Beauty            2050069  77.430128        392    3.065816
# 25              Morphe            1981741  78.119770        392    3.031122

# %% [markdown]
# ****************

# %% [markdown]
# ## 2- EDA (univariate + bi-variate + multivariate) to get insights about my data.

# %%
# Price
sns.kdeplot(df['Price_USD'])
plt.title('Price USD')
plt.show()
# Product_Size
sns.kdeplot(df['Product_Size'])
plt.title('Product Size')
plt.show()
# Rating
sns.kdeplot(df['Rating'])
plt.title('Rating')
plt.show()

# %%
GenderTaget_Values = df['Gender_Target'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(GenderTaget_Values,labels = GenderTaget_Values.index, autopct='%.1f%%', startangle=90, colors=sns.color_palette("pastel"))
plt.title('Distribution of Gender Target')
plt.show()

# %%
df.columns
# Out:
# Index(['Product_Name', 'Brand', 'Category', 'Usage_Frequency', 'Price_USD',
#        'Rating', 'Number_of_Reviews', 'Product_Size', 'Skin_Type',
#        'Gender_Target', 'Packaging_Type', 'Main_Ingredient', 'Cruelty_Free',
#        'Country_of_Origin'],
#       dtype='object')

# %%
column_name = 'Rating'

if column_name in df.columns:
    value_counts = df[column_name].value_counts() # count series
    plt.figure(figsize=(10, 10))  # figure size
    value_counts.plot(kind='pie', autopct='%1.1f%%')
    plt.title(f'Pie Chart of {column_name}')  
    plt.show()
else:
    print(f"Column '{column_name}' not found.")

# %%
column_name = 'Main_Ingredient'

if column_name in df.columns:
    value_counts = df[column_name].value_counts() # count series
    plt.figure(figsize=(10, 10))  # figure size
    value_counts.plot(kind='pie', autopct='%1.1f%%')
    plt.title(f'Pie Chart of {column_name}')  
    plt.show()
else:
    print(f"Column '{column_name}' not found.")

# %% [markdown]
# ### Cruelty_Free mean have not been tested on animals at any stage of their development
#
# True: The product is certified as cruelty-free, meaning it was not tested on animals at any stage of production.
#
# False: The product is not cruelty-free, implying it may have been tested on animals or is from a brand that does not guarantee animal-free testing.

# %%
column_name = 'Cruelty_Free' # have not been tested on animals at any stage of their development

if column_name in df.columns:
    value_counts = df[column_name].value_counts() # count series
    plt.figure(figsize=(10, 10))  # figure size
    value_counts.plot(kind='pie', autopct='%1.1f%%')
    plt.title(f'Pie Chart of {column_name}')  
    plt.show()
else:
    print(f"Column '{column_name}' not found.")

# %%
# Calculate the average rating per skin type
Skin_Type_Satisfaction = df.groupby(by='Skin_Type')['Rating'].mean().reset_index()

# Plot the line chart
plt.figure(figsize=(7, 3))
sns.lineplot(data=Skin_Type_Satisfaction, x='Skin_Type', y='Rating', marker='o', color='lightblue', linewidth=2.5)

# Add plot details
plt.title('Average Rating by Skin Type')
plt.xlabel('Skin Type')
plt.ylabel('Average Rating')
plt.grid(True)

# Display the plot
plt.show()

# %%
# Pivot table
prodact_effect = df.pivot_table(index='Main_Ingredient', columns='Skin_Type', values='Rating', aggfunc='mean')

# Heatmap figure
plt.figure(figsize=(12, 6))
sns.heatmap(prodact_effect, annot=True, cmap='coolwarm', fmt='.1f', linewidths=.5)
plt.title('Heatmap of Ratings by Main Ingredient and Skin Type')
plt.xlabel('Skin Type')
plt.ylabel('Main Ingredient')
plt.xticks(rotation=45) 
plt.yticks(rotation=0)  
plt.show()

# %%
# Selecting only the numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Creating the heatmap for the correlation matrix of numeric columns
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', linewidths=1)
plt.title('Correlation Matrix of Numeric Features in Beauty Product Dataset')
plt.show()

# %%
# Categorical Variable: Packaging Type
print("Packaging Type Distribution:")
print(df['Packaging_Type'].value_counts()) #
# Out:
# Packaging Type Distribution:
# Packaging_Type
# Jar        2567
# Bottle     2532
# Stick      2529
# Spray      2528
# Compact    2454
# Tube       2390
# Name: count, dtype: int64

# %%
# Plot a bar chart to visualize the distribution
plt.figure(figsize=(8, 6))
sns.countplot(x='Packaging_Type', data=df)
plt.title('Packaging Type Distribution')
plt.xlabel('Packaging Type')
plt.ylabel('Frequency')
plt.show()

# %%
top_brands = df['Brand'].value_counts().nlargest(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_brands.index, y=top_brands.values)
plt.title('Top 10 Popular Brands')
plt.xlabel('Brand')
plt.ylabel('Number of Products')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 1) "Which category of beauty products has the most variety?"

# %%
category_distribution = df['Category'].value_counts()
category_distribution.plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
plt.figure(figsize=(10, 6))
category_distribution.plot(kind='bar')
plt.title('Distribution of Products by Category')
plt.xlabel('Category')
plt.ylabel('Number of Products')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y=df['Category'], order=df['Category'].value_counts().index, palette='coolwarm')
plt.title('Distribution of Product Categories')
plt.xlabel('Count')
plt.ylabel('Category')
plt.grid(True)
plt.show()

# %% [markdown]
# Top Brands by Number of Products

# %%
plt.figure(figsize=(12, 6))
top_brands_count = df['Brand'].value_counts().head(10)
sns.barplot(x=top_brands_count.values, y=top_brands_count.index, palette='magma')
plt.title('Top Brands by Number of Products')
plt.xlabel('Number of Products')
plt.ylabel('Brand')
plt.grid(True)
plt.show()

# %%
# Numeric Variable: Price
print("Price Distribution:")
print(df['Price_USD'].describe())
# Plot a histogram to visualize the distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['Price_USD'], kde=True)
plt.title('Price Distribution')
plt.xlabel('Price_USD')
plt.ylabel('Frequency')
plt.show()
# Out:
# Price Distribution:
# count    15000.000000
# mean        80.134108
# std         40.402983
# min         10.000000
# 25%         45.480000
# 50%         80.040000
# 75%        114.760000
# max        149.990000
# Name: Price_USD, dtype: float64

# %%
# Numeric Variable: Rating
print("Rating Distribution:")
print(df['Rating'].describe())
# Plot a histogram to visualize the distribution
plt.figure(figsize=(8, 6))
sns.histplot(df['Rating'], kde=True)
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()
# Out:
# Rating Distribution:
# count    15000.000000
# mean         3.002327
# std          1.168029
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: Rating, dtype: float64

# %%
# Price Distribution by Country of Origin
plt.figure(figsize=(12, 6))
sns.boxplot(x='Country_of_Origin', y='Price_USD', data=df, palette='coolwarm', order=df['Country_of_Origin'].value_counts().head(10).index)
plt.title('Price Distribution by Country of Origin')
plt.xticks(rotation=45)
plt.xlabel('Country of Origin')
plt.ylabel('Price (USD)')
plt.grid(True)
plt.show()

# %% [markdown]
# What is the Top Selling Product Category?

# %%
perf_category = df.pivot_table(
    index = 'Category',
    aggfunc = {'Product_Name' : 'count', 'Rating' : 'mean', 'Number_of_Reviews' : 'sum'}
    ).reset_index()

perf_category = perf_category.rename(columns={'Product_Name': 'Number_of_Products'})

plt.figure(figsize=(12, 6))
sns.barplot(data=perf_category.sort_values(by='Number_of_Products', ascending = False).head(10), x='Category', y='Number_of_Products', palette='coolwarm')

plt.title('Top 10 Best Sellers Product Categories')
plt.xlabel('Category')
plt.ylabel('Total Numbers of Products')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Average Price of Top 10 Brands

# %%
# Set up the figure
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar plot for total number of products
bars = ax1.bar(top_brands_10['Brand'], top_brands_10['Total_Nop'], color='lightblue', label='Total Products')
ax1.set_xlabel('Brand')
ax1.set_ylabel('Total Number of Products')
ax1.tick_params(axis='y')
ax1.set_title('Total Number of Products and Average Price')

# Rotate and align the tick labels so they look better
plt.setp(ax1.get_xticklabels(), rotation=45, ha = 'right')

# Create a second y-axis for the average rating
ax2 = ax1.twinx()
line = ax2.plot(top_brands_10['Brand'], top_brands_10['Avg_price'], color='red', label='Average Price')
ax2.set_ylabel('Average Price')
ax2.tick_params(axis='y')

# Combine legends
lines = line + [bars]
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='upper right')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Which countries are the leading producers of beauty products?

# %%
country_counts = df['Country_of_Origin'].value_counts().nlargest(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=country_counts.index, y=country_counts.values)
plt.title('Top 10 Countries of Origin for Beauty Products')
plt.xlabel('Country')
plt.ylabel('Number of Products')
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(df)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# c:\My Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#df = px.data.tips()
#df
